# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv("Sequence24.csv")
file
# Out:
#                        Variation ID vg0112116426 vg0128525986 vg0130976864  \
# 0                        Chromosome        chr01        chr01        chr01
# 1                          Position     12116426     28525986     30976864
# 2                    Variation Type          SNP          SNP          SNP
# 3                         Reference            G            A            A
# 4                    Primary Allele            G            A            G
# ...                             ...          ...          ...          ...
# 4727  W326 (Haolvguangnian) Imputed            G            A            G
# 4728         W327 (JinghuB) Imputed            G            A            A
# 4729    W328 (Sibeitichao6) Imputed            G            A            A
# 4730       W329 (GPNO_5055) Imputed            A          DEL            G
# 4731      W330 (ASWINA_330) Imputed            G            G            G
#
# ...

# %%
data = file.iloc[4][1:]
initial = np.array(data)
primary = np.array('Primary')
primary = np.append(primary, initial)
primary = primary.astype('U')
np.savetxt("Primary.csv", primary, delimiter = ",", fmt = "%s")
