# %%
import pandas as pd
Imp_VarID = pd.read_excel("Imputed_Genotype_VarID.xlsx")
Imp_VarID.insert(10, "Plant_Height(cm)", "0")
Imp_VarID.to_excel("Mapped_set(Imputed).xlsx", index = False)

# %%
import pandas as pd
Raw_VarID = pd.read_excel("Raw_Genotype_VarID.xlsx")
Raw_VarID.insert(10, "Plant_Height(cm)", "0")
Raw_VarID.to_excel("Mapped_set(Raw).xlsx", index = False)

# %%
Mapped_1 = pd.read_excel("Mapped_set(Imputed).xlsx")
Mapped_1.rename(columns = {'Variation ID':'Cultivar ID'}, inplace = True)

# %%
#Mapped_1['Cultivar ID'] = Mapped_1['Cultivar ID'].str.split(" ", n = 1, expand = False)
for i in range(len(Mapped_1["Cultivar ID"])):
    Mapped_1["Cultivar ID"][i]=Mapped_1["Cultivar ID"][i][0]
Mapped_1
# Out:
# C:\Users\UMANG\AppData\Local\Temp\ipykernel_12128\2013678574.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mapped_1["Cultivar ID"][i]=Mapped_1["Cultivar ID"][i][0]
#      Cultivar ID vg0130976864 vg0135617816 vg0138428840 vg0405463422  \
# 0              C        chr01        chr01        chr01        chr04
# 1              P     30976864     35617816     38428840      5463422
# 2              V          SNP          SNP          SNP          SNP
# 3              R            A            C            T            G
# 4              P            G            C            T            G
# ...          ...          ...          ...          ...          ...
# 4727           W            G            C            T            G
# ...

# %%
Mapped_1.to_csv("Mapped_set_CSV(Imputed).csv", index = False)

# %%
Mapped_2 = pd.read_excel("Mapped_set(Raw).xlsx")
Mapped_2
# Out:
#                    Variation ID vg0130976864 vg0135617816 vg0138428840  \
# 0                    Chromosome        chr01        chr01        chr01
# 1                      Position     30976864     35617816     38428840
# 2                Variation Type          SNP          SNP          SNP
# 3                     Reference            A            C            T
# 4                Primary Allele            G            C            T
# ...                         ...          ...          ...          ...
# 4727  W326 (Haolvguangnian) Raw            G            C            T
# 4728         W327 (JinghuB) Raw            A            C            T
# 4729    W328 (Sibeitichao6) Raw            A            N            T
# 4730       W329 (GPNO_5055) Raw            G            C            T
# 4731      W330 (ASWINA_330) Raw            G            N            N
#
#      vg0405463422 vg0713178880 vg0819793460 vg1019044175 vg1123563633  \
# ...

# %%
Mapped_2.rename(columns = {"Variation ID":"Cultivar ID"}, inplace = True)

# %%
Mapped_2['Cultivar ID'] = Mapped_2["Cultivar ID"].str.split(" ", n = 1, expand = False)

# %%
for i in range(len(Mapped_2['Cultivar ID'])):
    Mapped_2['Cultivar ID'][i] = Mapped_2['Cultivar ID'][i][0]
Mapped_2
# Out:
# C:\Users\UMANG\AppData\Local\Temp\ipykernel_12128\545963648.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mapped_2['Cultivar ID'][i] = Mapped_2['Cultivar ID'][i][0]
#      Cultivar ID vg0130976864 vg0135617816 vg0138428840 vg0405463422  \
# 0     Chromosome        chr01        chr01        chr01        chr04
# 1       Position     30976864     35617816     38428840      5463422
# 2      Variation          SNP          SNP          SNP          SNP
# 3      Reference            A            C            T            G
# 4        Primary            G            C            T            G
# ...          ...          ...          ...          ...          ...
# 4727        W326            G            C            T            G
# ...

# %%
Mapped_2.to_csv("Mapped_set_CSV(Raw).csv", index = False)

# %%
plant_height = pd.read_excel("Plant_Height.xlsx")

# %%
plant_height.to_csv("Plant_Height(CSV).csv", index = False)
